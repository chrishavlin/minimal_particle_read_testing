# %%
import yt
from yt.config import ytcfg

# %%
ytcfg.set("yt", "internals", "dask_allowed", True) # the new loader
ytcfg.set("yt", "internals", "dask_enabled", True) # with delay

# %%
from yt.utilities.parallel_tools.dask_helper import dask_client
dask_client.start_client(n_workers=2)

# %%
dask_client.client
# Out:
# <Client: 'inproc://192.168.1.145/26790/1' processes=2 threads=2, memory=31.20 GiB>

# %%
fn = "snapshot_033/snap_033.0.hdf5"
field = ("PartType0", "Density")

# %%
# %%time
ds = yt.load(fn)
ad = ds.sphere(ds.domain_center, ds.domain_width.min()/4.)
data_new_dask = ad[field]
# Out:
# yt : [INFO     ] 2022-06-03 16:01:14,591 Parameters: current_time              = 4.343952725460923e+17 s
# yt : [INFO     ] 2022-06-03 16:01:14,592 Parameters: domain_dimensions         = [1 1 1]
# yt : [INFO     ] 2022-06-03 16:01:14,593 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-06-03 16:01:14,593 Parameters: domain_right_edge         = [25. 25. 25.]
# yt : [INFO     ] 2022-06-03 16:01:14,594 Parameters: cosmological_simulation   = 1
# yt : [INFO     ] 2022-06-03 16:01:14,594 Parameters: current_redshift          = -4.811891664902035e-05
# yt : [INFO     ] 2022-06-03 16:01:14,594 Parameters: omega_lambda              = 0.762
# yt : [INFO     ] 2022-06-03 16:01:14,594 Parameters: omega_matter              = 0.238
# yt : [INFO     ] 2022-06-03 16:01:14,595 Parameters: omega_radiation           = 0.0
# yt : [INFO     ] 2022-06-03 16:01:14,595 Parameters: hubble_constant           = 0.73
# ...

# %%
fn = "snapshot_028_z000p000/snap_028_z000p000.0.hdf5"
ds = yt.load(fn)
# Out:
# yt : [INFO     ] 2022-06-03 15:36:09,491 Parameters: current_time              = 4.361428036047735e+17 s
# yt : [INFO     ] 2022-06-03 15:36:09,492 Parameters: domain_dimensions         = [1 1 1]
# yt : [INFO     ] 2022-06-03 15:36:09,493 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-06-03 15:36:09,494 Parameters: domain_right_edge         = [8.47125 8.47125 8.47125]
# yt : [INFO     ] 2022-06-03 15:36:09,494 Parameters: cosmological_simulation   = 1
# yt : [INFO     ] 2022-06-03 15:36:09,494 Parameters: current_redshift          = 2.220446049250313e-16
# yt : [INFO     ] 2022-06-03 15:36:09,495 Parameters: omega_lambda              = 0.693
# yt : [INFO     ] 2022-06-03 15:36:09,495 Parameters: omega_matter              = 0.307
# yt : [INFO     ] 2022-06-03 15:36:09,495 Parameters: omega_radiation           = 0.0
# yt : [INFO     ] 2022-06-03 15:36:09,495 Parameters: hubble_constant           = 0.6777

# %%
ds.field_list
# Out:
# yt : [INFO     ] 2022-06-03 15:27:27,701 Allocating for 1.329e+07 particles
# Initializing coarse index : 100%|███████████████| 32/32 [00:01<00:00, 20.05it/s]
# yt : [INFO     ] 2022-06-03 15:27:29,311 Updating index_order2 from 2 to 2
# Initializing refined index: 100%|███████████████| 32/32 [00:05<00:00,  6.18it/s]
# [('PartType0', 'AExpMaximumTemperature'),
#  ('PartType0', 'Carbon'),
#  ('PartType0', 'Coordinates'),
#  ('PartType0', 'Density'),
#  ('PartType0', 'Entropy'),
#  ('PartType0', 'GroupNumber'),
#  ('PartType0', 'Helium'),
#  ('PartType0', 'HostHalo_TVir_Mass'),
#  ('PartType0', 'Hydrogen'),
#  ('PartType0', 'InternalEnergy'),
#  ('PartType0', 'Iron'),
#  ('PartType0', 'IronMassFracFromSNIa'),
#  ('PartType0', 'Magnesium'),
#  ('PartType0', 'Mass'),
#  ('PartType0', 'MaximumTemperature'),
#  ('PartType0', 'MetalMassFracFromAGB'),
#  ('PartType0', 'MetalMassFracFromSNII'),
#  ('PartType0', 'MetalMassFracFromSNIa'),
#  ('PartType0', 'MetalMassWeightedRedshift'),
# ...

# %%
ytcfg.set("yt", "internals", "dask_allowed", True) # the new loader
ytcfg.set("yt", "internals", "dask_enabled", True) # with delay

# %%
# %%time
ds = yt.load(fn)
ad = ds.sphere(ds.domain_center, ds.domain_width.min()/8.)
data_new_dask = ad[field]
# Out:
# yt : [INFO     ] 2022-06-03 16:00:11,124 Parameters: current_time              = 4.343952725460923e+17 s
# yt : [INFO     ] 2022-06-03 16:00:11,125 Parameters: domain_dimensions         = [1 1 1]
# yt : [INFO     ] 2022-06-03 16:00:11,126 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-06-03 16:00:11,127 Parameters: domain_right_edge         = [25. 25. 25.]
# yt : [INFO     ] 2022-06-03 16:00:11,127 Parameters: cosmological_simulation   = 1
# yt : [INFO     ] 2022-06-03 16:00:11,127 Parameters: current_redshift          = -4.811891664902035e-05
# yt : [INFO     ] 2022-06-03 16:00:11,127 Parameters: omega_lambda              = 0.762
# yt : [INFO     ] 2022-06-03 16:00:11,128 Parameters: omega_matter              = 0.238
# yt : [INFO     ] 2022-06-03 16:00:11,128 Parameters: omega_radiation           = 0.0
# yt : [INFO     ] 2022-06-03 16:00:11,128 Parameters: hubble_constant           = 0.73
# ...

# %%
ytcfg.set("yt", "internals", "dask_allowed", False) # the new loader
ytcfg.set("yt", "internals", "dask_enabled", True) # with delay

# %%
# %%time
ds = yt.load(fn)
ad = ds.sphere(ds.domain_center, ds.domain_width.min()/8.)
data_new_dask = ad[field]
# Out:
# yt : [INFO     ] 2022-06-03 16:00:37,218 Parameters: current_time              = 4.343952725460923e+17 s
# yt : [INFO     ] 2022-06-03 16:00:37,220 Parameters: domain_dimensions         = [1 1 1]
# yt : [INFO     ] 2022-06-03 16:00:37,221 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-06-03 16:00:37,222 Parameters: domain_right_edge         = [25. 25. 25.]
# yt : [INFO     ] 2022-06-03 16:00:37,222 Parameters: cosmological_simulation   = 1
# yt : [INFO     ] 2022-06-03 16:00:37,223 Parameters: current_redshift          = -4.811891664902035e-05
# yt : [INFO     ] 2022-06-03 16:00:37,223 Parameters: omega_lambda              = 0.762
# yt : [INFO     ] 2022-06-03 16:00:37,223 Parameters: omega_matter              = 0.238
# yt : [INFO     ] 2022-06-03 16:00:37,224 Parameters: omega_radiation           = 0.0
# yt : [INFO     ] 2022-06-03 16:00:37,224 Parameters: hubble_constant           = 0.73
# ...
